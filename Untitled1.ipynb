# %%
import dash
import numpy as np
import pandas as pd
import plotly.graph_objs as go
import dash_core_components as dcc
import dash_html_components as html
import dash_bootstrap_components as dbc
from dash.dependencies import Input,Output,State


data={'a':'10px'}    
datas={'a':'15px'}  
datass={'a':'0px'}
inp_style={'width':'10px','height':'10px'}
PROJ_LOGO = "assets/filter.png"
PROJ_LOGO1="assets/dev.png"
PROJ_LOGO2="assets/news.png"
###############################---CSS---###################################
#grid layout
container= {
    'display':'grid',
    'grid-template-columns':'repeat(3, 1fr)',
    'grid-template-rows':'repeat(3, minmax(100px, auto))',
    'grid-padding': '1em',
    'margin-top':'2rem',
    'margin-left':'3rem'
}

#placeholder layout
placeholder = {
    'background': "#eee",
    'border-style':'solid',
    'border-size':'0.5em',
    'border-color':'#ddd'
}

#Genrating Server 
app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])

###########################-------Navbar-----############################

dropdown= dcc.Dropdown(id='ddn',
                    options=[
                          {'label':'Amazon','value':'az'},
                          {'label':'Aliexpress','value':'ae'},
                          {'label':'Alibaba','value':'ab'},
                          {'label':'Flikpart','value':'fp'},
                          {'label':'Daraz','value':'dz'}],
                            value=['ae'],
                            multi=True,
                            disabled=False,
                            placeholder='select site for data analysis',
                           
                           
                      )

#Navbar Body
navbar = dbc.Navbar(
    [
        html.A(
            # Use row and col to control vertical alignment of logo / brand
            dbc.Row(
                [
                    dbc.Col(html.Img(src=PROJ_LOGO, height="30px",className='logo',id='_sidebar')),
                    dbc.Col(dbc.NavbarBrand("Buying Au""tomizer", className="ml-2")),
                ],
                align="center",
                no_gutters=True,
            ),
                  

        ),
       
        dbc.NavbarToggler(id="navbar-toggler"),
        dbc.Collapse(dropdown,id="navbar-collapse")
                            
                                
        ]
    ,
    color="dark",
    dark=True,
    style={'position':'fixed','width':'100%','z-index':'1000'},
   
)





#########################-------Navbar End-----###########################


########################------Sidebar-------##############################


def side_bar():
        div=html.Nav([
        
            html.Ul([  
                html.Li([html.Br(),
                html.A(children=[
                        html.I('BA',className=" text-light font-weight-bold ")
                                ],style={'margin-left':'23.5px'}
                      )                 
                    ]),
                html.Li([
                    html.Hr(style={'width':'40px',
                                   'margin-left':'-1px',
                                   'border-top': '1px solid white'},
                            )
                ],className='container'),
                 html.Li([
                    html.A(href="#",
                            children=[
                        html.I([],className="fa fa-bar-chart-o fa-2x"),
                        html.Span([""],className='nav-text') 
                            ],style={'margin-left':'20px'})
                  
                ],className=""),
                
###########################################################################               
#--------  List Data Start Here for Detail Analysis as Categories  -------#                
###########################################################################                
                
        html.Li([html.A(children=[
            
                    html.Div([ 
####---------------------Main Collapse Trigger------------------------#####
                        
                html.Li([
                    html.A(href="#",children=[
                        html.I([],className="fa fa-list fa-2x "),
                        html.Span([""],className='nav-text') 
                     ])],className="has-subnav",id='collapse-button'),
     
            
#####################--------Main collapse body--------####################           
           dbc.Collapse(
            html.Li([                         
#################         First Outer Div  Data         ###################
                
              html.Div([
                    #First Element  
                    dcc.Checklist(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':data['a']},
                         inputStyle=inp_style
       
                    ) ,         
                           
######---------------First Trigger of Inside Collapse----------------###### 
              
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-bar-chart-o fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']},id='tyyy')
                ])
                    ],className='d-flex',id='collapse-button1'),
                              
                        
######################------ [1st] Inner Colapse Body-------###############    
            dbc.Collapse(  
              html.Li([                         
     ###########---- [1st] First Inner Div of Data-----###########
                  
             html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']},
                        inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-18px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
    ###########---- [1st] Second Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
 
     ###########---- [1st]  Third Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
     ###########----  [1st] Fourth Inner Div of Data-----###########  
                  
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                    ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
    ###########---- [1st]  Fifth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                    ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
   ###########---- [1st]  Sixth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                        ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex')
                                                                          
              
              
              ]),
            id='inner-collapse1'
            ),
                    
                    
                    
                
                
                
#################        Second Outer Div  Data         ####################
                
                
                
                    html.Div([    
                    #First Element  
                    dcc.Checklist(
                    options=[
                        {'label':'','value': 'shs'}, 
                        ],style={'margin-left':data['a']}
                    ,inputStyle=inp_style
       
                    ) ,
                
######---------------Second Trigger of Inside Collapse----------------######
                     html.A(href="#",
                            children=[
                        html.I([],className="fa fa-cogs fa-2x ss text-light"),
                        html.Span([""],className='nav-text') 
                            ],style={'margin-top':'-18px','z-index':'-1',
                                     'margin-left':datass['a']})
                    
                    ],className='d-flex',id='collapse-button2'),
                    
                     dbc.Collapse(  
              html.Li([                         
          ###########---- [2nd] First Inner Div of Data-----###########
                  
             html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                    ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [2nd] Second Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                    ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
 
         ###########---- [2nd] Third Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                   , inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [2nd] Fourth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                            ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [2nd] Fifth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                    ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [2nd] Sixth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
       , inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-18px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex')
                                                                          
              
              
              ]),
            id='inner-collapse2'
            ),
        
                
                
                
                
                    
#################        Third Outer Div  Data         ####################
                
                
                
                    html.Div([                     
                    #First Element  
                    dcc.Checklist(
                    options=[
                        {'label':'','value': 'clt'}, 
                        ],style={'margin-left':data['a']},
                        inputStyle=inp_style
       
                    ) ,
                  
 ######---------------Third Trigger of Inside Collapse----------------######
                        
                        
                     html.A(href="#",
                            children=[
                        html.I([],className="fa fa-rss fa-2x ss text-light"),
                        html.Span([""],className='nav-text') 
                            ],style={'margin-top':'-18px','z-index':'-1'
                                     ,'margin-left':datass['a']})
                    ],className='d-flex',id='collapse-button3'),
                    
                 dbc.Collapse(  
              html.Li([                         
          ###########---- [3rd] First Inner Div of Data-----###########
                  
             html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
       , inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [3rd] Second Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
       , inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
 
         ###########---- [3rd] Third Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
        ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [3rd] Fourth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
       , inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [3rd] Fifth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
        ,inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [3rd] Sixth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
       , inputStyle=inp_style
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex')
                                                                          
              
              
              ]),
            id='inner-collapse3'
            ),
                    
      
                
                
                    
#################        Fourth Outer Div  Data         ###################
                
                
                    html.Div([                        
                    #First Element  
                    dcc.Checklist(
                    options=[
                        {'label':'','value': 'frg'}, 
                        ],style={'margin-left':data['a']}
                       ,inputStyle=inp_style
                    ) ,
                
######---------------Fourth Trigger of Inside Collapse----------------####      
                    
                    html.A(href="#",
                            children=[
                        html.I([],className="fa fa-cogs fa-2x ss text-light"),
                        html.Span([""],className='nav-text') 
                            ],style={'margin-top':'-18px','z-index':'-1'
                                     ,'margin-left':datass['a']})
                    ],className='d-flex',id='collapse-button4'),
                    
                    dbc.Collapse(  
              html.Li([
        ###########---- [4th] First Inner Div of Data-----###########
                  
             html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                                     ,inputStyle=inp_style

                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [4th] Second Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                       ,inputStyle=inp_style       
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
 
         ###########---- [4th] Third Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                       ,inputStyle=inp_style       
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [4th] Fourth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                       ,inputStyle=inp_style       
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [4th] Fifth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                        ,inputStyle=inp_style      
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [4th] Sixth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                       ,inputStyle=inp_style       
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex')
                                                                          
              
              
              ]),
            id='inner-collapse4'
            ),
                
                
                    
                    
#################        Fifth Outer Div  Data         ###################
                
                
                    html.Div([                        
                    #First Element  
                    dcc.Checklist(
                    options=[
                        {'label':'','value': 'hdf'}, 
                        ],style={'margin-left':data['a']}
                       ,inputStyle=inp_style
                    ),      
                        
######---------------Fifth Trigger of Inside Collapse----------------####       
                   
                        
                    html.A(href="#",
                            children=[
                        html.I([],className="fa fa-tasks fa-2x ss text-light"),
                        html.Span([""],className='nav-text') 
                            ],style={'margin-top':'-18px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ],className='d-flex',id='collapse-button5'),
                
                
            dbc.Collapse(  
              html.Li([    
        ###########---- [5th] First Inner Div of Data-----###########
                  
             html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                       ,inputStyle=inp_style      
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [5th] Second Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                       ,inputStyle=inp_style       
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
 
         ###########---- [5th] Third Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                        ,inputStyle=inp_style      
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [4th] Fourth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                         ,inputStyle=inp_style     
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [5th] Fifth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                       ,inputStyle=inp_style       
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [5th] Sixth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                       ,inputStyle=inp_style       
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex')
                                                                          
              
              
              ]),
            id='inner-collapse5'
            ),     
                        
      
                
                
#################      Sixth Outer Div  Data         ###################
                
                
                    html.Div([                        
                    #First Element  
                    dcc.Checklist(
                    options=[
                        {'label':'','value': 'srts'}, 
                        ],style={'margin-left':data['a']}
                       ,inputStyle=inp_style
                    ), 
                        
                        
######---------------Sixth Trigger of Inside Collapse----------------####        
                   
                        
                    html.A(href="#",
                            children=[
                        html.I([],className="fa fa-map-marker fa-2x ss text-light"),
                        html.Span([""],className='nav-text') 
                            ],style={'margin-top':'-18px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ],className='d-flex',id='collapse-button6'),
                
                
                dbc.Collapse(  
              html.Li([    
        ###########---- [6th] First Inner Div of Data-----###########
                  
             html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                         ,inputStyle=inp_style     
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [6th] Second Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                       ,inputStyle=inp_style       
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
 
         ###########---- [6th] Third Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                        ,inputStyle=inp_style      
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [6th] Fourth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                       ,inputStyle=inp_style       
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [6th] Fifth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                        ,inputStyle=inp_style      
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                        children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex'),
                  
                  
         ###########---- [6th] Sixth Inner Div of Data-----###########               
              html.Div([    
                    #First Element  
                    dcc.RadioItems(
                    options=[
                        {'label':'','value': 'tys'}, 
                        ],style={'margin-left':datas['a']}
                        ,inputStyle=inp_style      
                    ) ,                  
                        
            #Icon For Visulaizing
            html.Div([
                html.Li([
                     html.A(href="#",
                  children=[
                        html.I([],className="fa fa-map-marker fa-2x ss"),
                        html.Span([""],className='nav-text') 
                        ],style={'margin-top':'-20px','z-index':'-1',
                                     'margin-left':datass['a']})
                    ])
                    ]),      
                        
                ],className='d-flex')
                                                                          
              
              
              ]),
            id='inner-collapse6'
            ),    
                    
                    
                    
                    
            ]),id="outer-collapse"
           )])])],style={'margin-left':'20px'}),
###########################################################################               
#-------------------------  List Data End Here  --------------------------#                
###########################################################################                
      
               html.Li([
                    html.A(href="#",
                            children=[
                        html.I([],className="fa fa-table fa-2x"),
                        html.Span([""],className='nav-text') 
                            ],style={'margin-left':'23px'})
                  
                ],className="",id='side-table'),
               
                 html.Li([
                    html.A(href="#",
                            children=[
                        html.Img(src='assets/about.jpg',height="35px"),
                        html.Span([""],className='nav-text') 
                            ],style={'margin-left':'18px',
                                     'height':'5px',
                                     'width':'2px'})
                  
                ],className="",id='side-about'),
                
                ])
            ],className="main-menu")
        
        return div


#####################-----Sidebar Body End-------##########################


def aliexp():
    data=html.Div([

##########################--- Graph Body-----##############################

    dbc.CardDeck([   
        dbc.Card([html.Div(['Product Qualtiy'],style={'margin-left':'1rem',
                                                         'font-size':'25px'}
                           ,className=''),
           
                dcc.Graph(id='nice0',
                         figure={
                             'data':[go.Scatter(x=[d for d in range(1,200)],y=[s*np.random.randint(1,500,1)[0] for s in range(1,200)]
                                    ,name='Profit',line=dict(color='#ff33ff')),
                                     
                                    
                                     ]
                            , 'layout':{'showlegend':False,
                                     'plot_bgcolor':'#3d3d5c',
                                    'paper_bgcolor':'#3d3d5c',
                                    'paper_size':'20rem',
                                    'margin':{'l': 35, 'b': 25, 't': 0, 'r': 20},
                                    'legend':{'x': 0, 'y': 1},
                                    'font':{
                                        'color':'white'
                                        },
                                    "yaxis1":{
                                         "zeroline": False,
                                        },
                                    "xaxis1": {
      
                                        "gridcolor": "#47476b",
                                        "zerolinecolor": "#3d3d5c"
                                        }, 
      
          } ,
                                    
                         },className='styling1 text-light')
            ],id='styling5')
      ]),
        
###########################---Graph Body End---############################
        
############################----Cards Body------###########################         
         
      dbc.CardDeck([
        dbc.Card([
            dbc.CardBody([
                html.Img(src='assets/total-prod.png',className='img-style'),
                    html.H4("36000M", className="card-title text-right",
                             style={'margin-bottom':'-10px','margin-top':'-2rem'})
                ]),
             dbc.CardFooter(children=[
                html.Hr(style={'border-top': '1px solid white','margin-bottom':'8px'})
                                     ,"This is the footer"],style={'border':'white'})],className='card-style'),
            dbc.Card([
            dbc.CardBody([
                 html.Img(src='assets/total_count.png',className='img-style'),
                    html.H4("98040C", className="card-title text-right",
                             style={'margin-bottom':'-10px','margin-top':'-2rem'})
                ]),
            dbc.CardFooter(children=[
                html.Hr(style={'border-top': '1px solid white','margin-bottom':'8px'})
                                     ,"This is the footer"],style={'border':'white'})],className='card-style')
           
         
       
           , dbc.Card([
            dbc.CardBody([
                    html.Img(src='assets/rating.png',className='img-style'),
                    html.H4("4.9R", className="card-title text-right",
                            style={'margin-bottom':'-10px','margin-top':'-2rem'}),
                ]),
            dbc.CardFooter(children=[
                html.Hr(style={'border-top': '1px solid white','margin-bottom':'8px'})
                                     ,"This is the footer"],style={'border':'white'})],className='card-style'),
            
         
         
         
            dbc.Card([
            dbc.CardBody([
                   html.Img(src='assets/price.png',className='img-style'),
                    html.H4("1,450$", className="card-title text-right",
                             style={'margin-bottom':'-10px','margin-top':'-2rem'}),
              
                ]),
            dbc.CardFooter(children=[
                html.Hr(style={'border-top': '1px solid white','margin-bottom':'8px'})
                                     ,"This is the footer"],style={'border':'white'})],className='card-style'),
         
    ],className='card-setting '),
     

    
########################----Cards body End----#############################

 html.Div([
    dbc.CardDeck([   
        dbc.Card([
           
                    dcc.Graph(id='nice0',
                         figure={
                             'data':[go.Waterfall(x=list('123456789'),y=list('35126965'),name='Profit')]
                            , 'layout':{'showlegend':False,
                                    'plot_bgcolor':'#3d3d5c',
                                    'paper_bgcolor':'#3d3d5c',
                                    'paper_size':'20rem',
                                    'margin':{'l': 25, 'b': 25, 't': 0, 'r': 0},
                                    'legend':{'x': 0, 'y': 1},
                                    'showgrid':True,
                                    "gridcolor": "rgb(159, 197, 232)",
                                    'font':{
                                        'color':'white'
                                        },
                                     
                                    }   
                         },style={'height':'19rem'})
            
        ],style={'height':'18rem',"border":'#3d3d5c'}),
         dbc.Card([
           
                    dcc.Graph(id='nice2',
                         figure={
                             'data':[go.Bar(
                                 x=list('123456789'),y=list('35126965'),name='Profit',
                                 marker_color="rgba(0,0,0,0.0)",
                                 marker_line_color='#0066ff',
                                 marker_line_width=2,
                                 opacity=1
                                 )]
                            , 'layout':{'showlegend':False,
                                   'plot_bgcolor':'#3d3d5c',
                                    'paper_bgcolor':'#3d3d5c',
                                    'paper_size':'20rem',
                                    'margin':{'l': 25, 'b': 25, 't': 0, 'r': 0},
                                    'legend':{'x': 0, 'y': 1},
                                    
                                    'mode':'markers',
                                    'font':{
                                        'color':'white'
                                        },
                                    "yaxis1":{
                                         "gridcolor": "#47476b",
                                        "zerolinecolor": "#3d3d5c",
                                         "zeroline": False,
                                        },
                                    "xaxis1": {
      
                                        "gridcolor": "#47476b",
                                        "zerolinecolor": "#3d3d5c"
                                        }, 
                                    }   
                         },style={'height':'19rem'})                                
            ],style={'height':'18rem',"border":'#3d3d5c'}),

        dbc.Card([
           
                   dcc.Graph(id='nice1',
                         figure={
                             'data':[go.Scatter(x=list('123456789'),
                                                y=list('35126965'),
                                                name='Profit',
                                                mode='markers',
                                               )]
                            , 'layout':{'showlegend':False,
                                     'plot_bgcolor':'#3d3d5c',
                                    'paper_bgcolor':'#3d3d5c',
                                    'paper_size':'20rem',
                                    'margin':{'l': 25, 'b': 25, 't': 0, 'r': 0},
                                    'legend':{'x': 0, 'y': 1},
                                    'font':{
                                        'color':'white'
                                        }
                                    }   
                         },style={'height':'19rem'})
                
        ],style={'height':'18rem',"border":'#3d3d5c'}),
       
        ],className='card-setting')
    ])
     
    ],style={'margin-right':'0rem',
             'margin-top':'0rem'})

        
######################################################################
    return data



#########################-------Output Div--------#########################
#This is Content where our output will be show

content=html.Div(id='output',className='container-fluid CONTENT_STYLE')

##########-----Main Layout where all outputs digested------###########
app.layout=html.Div([     
   navbar,
   dbc.Collapse(side_bar(),id='sidebar_collapse'),
   content
   
       
],className='back-g')
########################-----Main Layout End-------########################   


########################------Callback Function-----#######################
#Callback Function works as MySQL Triggers/Javascript Events 
 


@app.callback(
    Output("sidebar_collapse", "is_open"),
    [Input("_sidebar", "n_clicks")],
    [State("sidebar_collapse", "is_open")],
)
def sidebar_collapse(n, is_open):
   if n:       
       return not is_open
   else:
       return not is_open



@app.callback(
    Output("navbar-collapse", "is_open"),
    [Input("navbar-toggler", "n_clicks")],
    [State("navbar-collapse", "is_open")],
)
def toggle_navbar_collapse(n, is_open):
   if n:
     return not is_open
   return  is_open
 

@app.callback(
    Output("outer-collapse", "is_open"),
    [Input("collapse-button", "n_clicks")],
    [State("outer-collapse", "is_open")],
)
def toggle_collapse(n, is_open):
    if n:
        return not is_open
    return is_open
#inner-collapse

@app.callback(
    Output("inner-collapse1", "is_open"),
    [Input("collapse-button1", "n_clicks")],
    [State("inner-collapse1", "is_open")],
)
def toggle_collapse(n, is_open):
    if n:
        return not is_open
    return is_open

@app.callback(
    Output("inner-collapse2", "is_open"),
    [Input("collapse-button2", "n_clicks")],
    [State("inner-collapse2", "is_open")],
)
def toggle_collapse(n, is_open):
    if n:
        return not is_open
    return is_open

@app.callback(
    Output("inner-collapse3", "is_open"),
    [Input("collapse-button3", "n_clicks")],
    [State("inner-collapse3", "is_open")],
)
def toggle_collapse(n, is_open):
    if n:
        return not is_open
    return is_open

@app.callback(
    Output("inner-collapse4", "is_open"),
    [Input("collapse-button4", "n_clicks")],
    [State("inner-collapse4", "is_open")],
)
def toggle_collapse(n, is_open):
    if n:
        return not is_open
    return is_open

@app.callback(
    Output("inner-collapse5", "is_open"),
    [Input("collapse-button5", "n_clicks")],
    [State("inner-collapse5", "is_open")],
)
def toggle_collapse(n, is_open):
    if n:
        return not is_open
    return is_open

@app.callback(
    Output("inner-collapse6", "is_open"),
    [Input("collapse-button6", "n_clicks")],
    [State("inner-collapse6" ,"is_open")],
)
def toggle_collapse(n, is_open):
    if n:
        return not is_open
    return is_open


value=''
@app.callback(Output('output','children'),[Input('ddn','value'),Input('side-about','n_clicks')])
def genrator(value_s,side_about):
    print(value_s)
    print(side_about)
    if side_about==None:
            global value
            for s in value_s:
                value+=s
            print(value)
            if value=='az':
                value=''
                return html.P('Welcome to Amazon')
            if value=='ae':
                value=''
                return aliexp()
            if value=='ab':
                value=''
                return html.Div([
                    html.Div([
                      html.Div([
                        html.P(["Some text inside the first card"],className="card-text")
                              ],className='card-body text-center')
                            ],className="card bg-primary")     ,
                     html.Div([
                      html.Div([
                        html.P(["Some text inside the first card"],className="card-text")
                              ],className='card-body text-center')
                            ],className="card bg-warning")     
                        ],className="card-columns")
            if value=='fp':
                value=''
                return html.Div([
                    html.Div(['Flex item 1'],className='p-2 bg-info'),
                    html.Div(["Flex item 2"], className="p-2 bg-warning"),
                    html.Div(["Flex item 3"],className='p-2 bg-primary')    
                    ],className='d-flex p-3 bg-secondary text-white')
            if value=='dz':
                value=''
                return html.Div([
                    "Icons made by",
                    html.A(href="https://www.flaticon.com/authors/freepik")
                    
                ])
            if value=='azae':
                value=''
                return html.P('Welcome to Amazon & Aliexpress!')
            if value=='azaeab':
                value=''
                return html.P('Welcome to Amazon , Aliexpress & Alibaba!')
            if value=='azaeabdz':
                value=''
                return html.P('Welcome to Amazon , Aliexpress , Alibaba & Daraz!')
            if value=='azaeabdzfp':
                value=''
                return html.P('Welcome to Amazon , Aliexpress , Alibaba , Daraz & Flikpart!')
            else:
                value=''
                return html.P(value)
    elif side_about!=None and value_s==[]:
        return html.H1(f'This is about this application developers {value_s,side_about}',style={'color':'white'})

       
        
if __name__=='__main__':
    app.run_server(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [11/Jul/2020 04:01:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2020 04:01:54] "GET /_dash-component-suites/dash_renderer/react@16.8.6.min.js?v=1.1.2&m=1576595738 HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2020 04:01:54] "GET /_dash-component-suites/dash_renderer/react-dom@16.8.6.min.js?v=1.1.2&m=1576595738 HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2020 04:01:54] "GET /_dash-component-suites/dash_renderer/prop-types@15.7.2.min.js?v=1.1.2&m=1576595738 HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jul/2020 04:01:54] "GET /_dash-component-suites/dash_core_components/highlight.pack.js?v=1.3.1&m=1576595950 HTTP/1.1" 200 -
# ...

# %%
import mysql.connector 

cnx = mysql.connector.connect(host='localhost',user='root',
                              password='khan@pakistan159',
                              auth_plugin='mysql_native_password')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-25-6605bac80d68> in <module>
#       3 cnx = mysql.connector.connect(host='localhost',user='root',
#       4                               password='khan@pakistan159',
# ----> 5                               auth_plugin='mysql_native_password')
#
# ~\Anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# --> 179         return MySQLConnection(*args, **kwargs)
#     180 Connect = connect  # pylint: disable=C0103
#     181
#
# ~\Anaconda3\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#      93
#      94         if len(kwargs) > 0:
# ---> 95             self.connect(**kwargs)
#      96
#      97     def _do_handshake(self):
#
# ...
